# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/drags/OSA_PiLA/gbif_download_summary.csv")
list = pd.read_excel("C:/Users/drags/OSA_PiLA/specieslist.xlsx")
# new = pd.read_csv("gbif_download_summary.csv")

list['number'] = df['']
list, df
# Out:
# (           scientific_name
#  0     Allobates talamancae
#  1          Atelopus varius
#  2        Incilius aucoinae
#  3       Incilius coniferus
#  4   Incilius melanochlorus
#  ..                     ...
#  57        Oedipina savagei
#  58         Oscaecilia osae
#  59   Dermophis glandulosus
#  60  Dermophis occidentalis
#  61   Gymnopis multiplicata
#
#  [62 rows x 1 columns],
#                       matched_species  successfully_downloaded
#  0                   Agalychnis annae                        4
#  1              Agalychnis callidryas                       11
#  2               Allobates talamancae                       40
#  3                    Atelopus varius                        0
#  4                   Boana rosenbergi                       46
#  5              Cochranella granulosa                       14
#  6           Craugastor crassidigitus                        2
#  7              Craugastor fitzingeri                       27
# ...
