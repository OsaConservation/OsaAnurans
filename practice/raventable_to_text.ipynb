# %%
import json

file = r"D:\Acoustics\Table 1.raventable"
with open(file, "r") as f:
    summary = json.load(f)
    name = summary["eventList"][0]["fileList"][0].split("\\")[-1].split(".")[0]
summary
# Out:
# {'TABLE_VERSION': 'v3',
#  'eventList': [{'id': 1,
#    'channel': 1,
#    'minTime': 236053858837,
#    'maxTime': 240264946708,
#    'minFreq': 2511.623648710029,
#    'maxFreq': 4744.181788244913,
#    'reference': '2021-04-14T11:40:21Z',
#    'fileList': ['D:\\Acoustics\\SWIFT29_2021-04-14\\SWIFT29_20210414_114021.wav'],
#    'annotationMap': {'Species': 'PHYVIT'}},
#   {'id': 2,
#    'channel': 1,
#    'minTime': 269168092673,
#    'maxTime': 273183315143,
#    'minFreq': 1674.4143463844478,
#    'maxFreq': 4651.1599518531975,
#    'reference': '2021-04-14T11:40:21Z',
#    'fileList': ['D:\\Acoustics\\SWIFT29_2021-04-14\\SWIFT29_20210414_114021.wav'],
#    'annotationMap': {'Species': 'PHYVIT'}},
#   {'id': 3,
#    'channel': 1,
#    'minTime': 333301950272,
#    'maxTime': 341198215511,
#    'minFreq': 1744.3618200775375,
#    'maxFreq': 5233.079953301221,
#    'reference': '2021-04-14T11:40:21Z',
# ...
